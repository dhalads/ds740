# %%
try
    from google.colab import drive
    drive.mount('/content/gdrive')

# %%
import os
print(os.getcwd())
# os.chdir("/content/gdrive/MyDrive/Documents/Segmentation")
os.chdir("c:\\Users\\djhalama\\Documents\\GitHub\\ds740")
print(os.getcwd())
# Out:
# c:\Users\djhalama\Documents\GitHub\ds740
# c:\Users\djhalama\Documents\GitHub\ds740

# %%
# %run -i FinalProject/ds740.py
# Out:
# 2.3.0
# Tokenization took: 38.22 ms
# Type conversion took: 4.64 ms
# Parser memory cleanup took: 0.00 ms
# Tokenization took: 19.12 ms
# Type conversion took: 4.04 ms
# Parser memory cleanup took: 0.00 ms
# The shape is (975, 25)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 975 entries, 2 to 1903
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age_at_diagnosis                975 non-null    float64
#  1   type_of_breast_surgery          975 non-null    object
#  2   cancer_type_detailed            975 non-null    object
#  3   cellularity                     975 non-null    object
#  4   chemotherapy                    975 non-null    int64
#  5   pam50_+_claudin-low_subtype     975 non-null    object
#  6   cohort                          975 non-null    int64
#  7   er_status_measured_by_ihc       975 non-null    object
# ...

# %%
# !python --version
# Out:
# Python 3.6.13
